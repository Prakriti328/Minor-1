# %% [markdown]
# <a href="https://colab.research.google.com/github/Prakriti328/Minor-1/blob/main/minor1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
dataset=pd.read_csv('salary_data.csv')
x=dataset.iloc[:,:-1].values
y=dataset.iloc[:,1].values
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=1/3,random_state=0)
from sklearn.linear_model import LinearRegression
regressor= LinearRegression()
regressor.fit(x_train,y_train)
v_train= plt
v_train.scatter(x_train,y_train,color='red')
v_train.plot(x_train,regressor.predict(x_train),color='blue')
v_train.title('salary vs experience')
v_train.xlabel('years of experience')
v_train.ylabel('salary')
v_train.show()

v_test =plt
v_test.scatter(x_test,y_test,color='red')
v_test.plot(x_train,regressor.predict(x_train),color='blue')
v_test.title('salary vs experience')
v_test.xlabel('years of experience')
v_test.ylabel('salary')
v_test.show()
